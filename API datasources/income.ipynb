# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy import stats 
from scipy.stats import linregress


# Output File (CSV)
output_data_file = "output_data/salaries.csv"

# %%
# Save config information
url = "https://datausa.io/api/data?Geography=16000US4260000&measure=Average%20Wage,Average%20Wage%20Appx%20MOE,Total%20Population,Total%20Population%20MOE%20Appx,Record%20Count&drilldowns=Gender&Employment%20Time%20Status=1&Detailed%20Occupation=291141,1191XX,533030,537062,412031&Record%20Count%3E=5"
# units = "imperial"


# Build query URL
query_url = f"{url}"
query_url
# Out:
# 'https://datausa.io/api/data?Geography=16000US4260000&measure=Average%20Wage,Average%20Wage%20Appx%20MOE,Total%20Population,Total%20Population%20MOE%20Appx,Record%20Count&drilldowns=Gender&Employment%20Time%20Status=1&Detailed%20Occupation=291141,1191XX,533030,537062,412031&Record%20Count%3E=5'

# %%
response = requests.get(query_url).json()
response
# Out:
# {'data': [{'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 70580.63570306363,
#    'Average Wage Appx MOE': 7787.381405961702,
#    'Total Population': 15276,
#    'Total Population MOE Appx': 3029.5955491433274,
#    'Record Count': 141,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '1191XX',
#    'Detailed Occupation': 'Other managers',
#    'Average Wage': 115279.15485869144,
#    'Average Wage Appx MOE': 8044.56391838343,
#    'Total Population': 85239,
#    'Total Population MOE Appx': 7103.747978839758,
#    'Record Count': 866,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 50504.629075994846,
#    'Average Wage Appx MOE': 2010.2457007634227,
#    'Total Population': 118008,
#    'Total Population MOE Appx': 8329.202825593333,
#    'Record Count': 1265,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 36499.6498220552,
#    'Average Wage Appx MOE': 1572.2622030195628,
#    'Total Population': 80362,
#    'Total Population MOE Appx': 6901.113219084553,
#    'Record Count': 853,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 53713.7382821609,
#    'Average Wage Appx MOE': 6478.151307996359,
#    'Total Population': 38595,
#    'Total Population MOE Appx': 4803.748107676571,
#    'Record Count': 377,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 69670.55326140873,
#    'Average Wage Appx MOE': 2283.970364001576,
#    'Total Population': 112896,
#    'Total Population MOE Appx': 8151.263207930433,
#    'Record Count': 1171,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '1191XX',
#    'Detailed Occupation': 'Other managers',
#    'Average Wage': 87194.49822794615,
#    'Average Wage Appx MOE': 8812.261547371932,
#    'Total Population': 51635,
#    'Total Population MOE Appx': 5548.669917416249,
#    'Record Count': 492,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 30100.72416329533,
#    'Average Wage Appx MOE': 7977.0284638266,
#    'Total Population': 5438,
#    'Total Population MOE Appx': 1809.4526874077515,
#    'Record Count': 41,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 29083.289519530532,
#    'Average Wage Appx MOE': 2174.415421012128,
#    'Total Population': 21812,
#    'Total Population MOE Appx': 3617.6750947889655,
#    'Record Count': 219,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2019,
#    'Year': '2019',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 34998.54108853473,
#    'Average Wage Appx MOE': 5276.688219860281,
#    'Total Population': 23279,
#    'Total Population MOE Appx': 3736.7757038783807,
#    'Record Count': 205,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 83065.51539662268,
#    'Average Wage Appx MOE': 14038.405006156008,
#    'Total Population': 14094,
#    'Total Population MOE Appx': 2910.3581582822353,
#    'Record Count': 134,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '1191XX',
#    'Detailed Occupation': 'Other managers',
#    'Average Wage': 105924.46862848008,
#    'Average Wage Appx MOE': 8392.373420615293,
#    'Total Population': 83834,
#    'Total Population MOE Appx': 7045.584301515997,
#    'Record Count': 843,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 50454.15282799535,
#    'Average Wage Appx MOE': 1866.2773952744583,
#    'Total Population': 124735,
#    'Total Population MOE Appx': 8556.353943682463,
#    'Record Count': 1285,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 36696.50969040095,
#    'Average Wage Appx MOE': 1961.2096020313293,
#    'Total Population': 81008,
#    'Total Population MOE Appx': 6927.912399647399,
#    'Record Count': 936,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 52598.29398322653,
#    'Average Wage Appx MOE': 5827.4295873998735,
#    'Total Population': 42448,
#    'Total Population MOE Appx': 5035.627175887831,
#    'Record Count': 377,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 67100.64640559387,
#    'Average Wage Appx MOE': 2193.771404044676,
#    'Total Population': 103828,
#    'Total Population MOE Appx': 7824.046820539053,
#    'Record Count': 1069,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '1191XX',
#    'Detailed Occupation': 'Other managers',
#    'Average Wage': 87815.76518463712,
#    'Average Wage Appx MOE': 8579.97700316148,
#    'Total Population': 44601,
#    'Total Population MOE Appx': 5160.572531859682,
#    'Record Count': 395,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 31418.805937154586,
#    'Average Wage Appx MOE': 4868.417592698289,
#    'Total Population': 6333,
#    'Total Population MOE Appx': 1952.4940158366783,
#    'Record Count': 53,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 29725.878206383397,
#    'Average Wage Appx MOE': 7671.169088483575,
#    'Total Population': 15321,
#    'Total Population MOE Appx': 3034.006994370604,
#    'Record Count': 186,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2018,
#    'Year': '2018',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 38291.085311046285,
#    'Average Wage Appx MOE': 6659.0838582812175,
#    'Total Population': 25366,
#    'Total Population MOE Appx': 3899.758355576344,
#    'Record Count': 238,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 80387.5292524763,
#    'Average Wage Appx MOE': 8351.43107516719,
#    'Total Population': 14033,
#    'Total Population MOE Appx': 2903.9787988122216,
#    'Record Count': 132,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 46920.18295756478,
#    'Average Wage Appx MOE': 2159.360101936477,
#    'Total Population': 117049,
#    'Total Population MOE Appx': 8293.165518648562,
#    'Record Count': 1205,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 37026.13617601296,
#    'Average Wage Appx MOE': 2362.956608108631,
#    'Total Population': 77767,
#    'Total Population MOE Appx': 6789.043745437291,
#    'Record Count': 820,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 53890.172534526355,
#    'Average Wage Appx MOE': 7916.569613806725,
#    'Total Population': 35987,
#    'Total Population MOE Appx': 4639.378567024403,
#    'Record Count': 364,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 67214.166706725,
#    'Average Wage Appx MOE': 2407.951810836023,
#    'Total Population': 104015,
#    'Total Population MOE Appx': 7829.034679319214,
#    'Record Count': 1084,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 32379.270410195142,
#    'Average Wage Appx MOE': 8515.78142956065,
#    'Total Population': 5022,
#    'Total Population MOE Appx': 1738.9150656665563,
#    'Record Count': 35,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 26691.990325900515,
#    'Average Wage Appx MOE': 2880.8483210958425,
#    'Total Population': 14575,
#    'Total Population MOE Appx': 2959.354970971307,
#    'Record Count': 154,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2017,
#    'Year': '2017',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 36084.46999293076,
#    'Average Wage Appx MOE': 5575.887299695561,
#    'Total Population': 26877,
#    'Total Population MOE Appx': 4013.339326481069,
#    'Record Count': 246,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 68129.08447160316,
#    'Average Wage Appx MOE': 9374.737873317727,
#    'Total Population': 11128,
#    'Total Population MOE Appx': 2586.7694794322006,
#    'Record Count': 112,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 47333.438450220696,
#    'Average Wage Appx MOE': 2180.591265354683,
#    'Total Population': 112145,
#    'Total Population MOE Appx': 8120.987959637961,
#    'Record Count': 1166,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 35233.155072151625,
#    'Average Wage Appx MOE': 1680.5603594084755,
#    'Total Population': 69645,
#    'Total Population MOE Appx': 6429.973482235003,
#    'Record Count': 793,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 49648.41920105613,
#    'Average Wage Appx MOE': 6261.089810592783,
#    'Total Population': 40904,
#    'Total Population MOE Appx': 4943.3278498244445,
#    'Record Count': 383,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 64723.68338400152,
#    'Average Wage Appx MOE': 1918.6607207567467,
#    'Total Population': 105260,
#    'Total Population MOE Appx': 7873.77936540808,
#    'Record Count': 1027,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 36137.982989064396,
#    'Average Wage Appx MOE': 6663.6435362667025,
#    'Total Population': 4115,
#    'Total Population MOE Appx': 1574.22016128314,
#    'Record Count': 40,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 28289.153297026787,
#    'Average Wage Appx MOE': 2929.681640076672,
#    'Total Population': 13588,
#    'Total Population MOE Appx': 2857.6601465514423,
#    'Record Count': 155,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2016,
#    'Year': '2016',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 31106.45618633664,
#    'Average Wage Appx MOE': 3195.410229906362,
#    'Total Population': 30139,
#    'Total Population MOE Appx': 4248.275986927075,
#    'Record Count': 264,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 68907.87305976807,
#    'Average Wage Appx MOE': 7856.027814096758,
#    'Total Population': 11210,
#    'Total Population MOE Appx': 2596.2266696317974,
#    'Record Count': 115,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 46087.886521691136,
#    'Average Wage Appx MOE': 1878.0942702634852,
#    'Total Population': 117767,
#    'Total Population MOE Appx': 8315.715849752376,
#    'Record Count': 1228,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 33792.24082690688,
#    'Average Wage Appx MOE': 1603.8125600291403,
#    'Total Population': 77155,
#    'Total Population MOE Appx': 6761.575169645143,
#    'Record Count': 842,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 47700.442837798626,
#    'Average Wage Appx MOE': 5678.849510661155,
#    'Total Population': 41356,
#    'Total Population MOE Appx': 4970.085723875826,
#    'Record Count': 381,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 64629.08175520099,
#    'Average Wage Appx MOE': 2131.0429358543192,
#    'Total Population': 98587,
#    'Total Population MOE Appx': 7624.898524989344,
#    'Record Count': 1014,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 26274.930133333335,
#    'Average Wage Appx MOE': 7505.241246812428,
#    'Total Population': 3750,
#    'Total Population MOE Appx': 1502.835977869389,
#    'Record Count': 40,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 28248.533596586203,
#    'Average Wage Appx MOE': 2844.966101487863,
#    'Total Population': 15701,
#    'Total Population MOE Appx': 3071.0633119845756,
#    'Record Count': 189,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2015,
#    'Year': '2015',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 28734.92122879413,
#    'Average Wage Appx MOE': 3369.9606819089367,
#    'Total Population': 21810,
#    'Total Population MOE Appx': 3617.100454932424,
#    'Record Count': 231,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 65841.13802545886,
#    'Average Wage Appx MOE': 9820.507819069951,
#    'Total Population': 13512,
#    'Total Population MOE Appx': 2849.578358998793,
#    'Record Count': 129,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 44708.86606590023,
#    'Average Wage Appx MOE': 1894.6654564305932,
#    'Total Population': 119514,
#    'Total Population MOE Appx': 8373.947642739826,
#    'Record Count': 1254,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 33659.893253259754,
#    'Average Wage Appx MOE': 2066.6487965911433,
#    'Total Population': 73932,
#    'Total Population MOE Appx': 6620.463302269277,
#    'Record Count': 797,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 1,
#    'Gender': 'Male',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 55570.49864715903,
#    'Average Wage Appx MOE': 8341.752534083873,
#    'Total Population': 39916,
#    'Total Population MOE Appx': 4883.268918512485,
#    'Record Count': 355,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '291141',
#    'Detailed Occupation': 'Registered nurses',
#    'Average Wage': 62452.38368661658,
#    'Average Wage Appx MOE': 2366.87128349608,
#    'Total Population': 99967,
#    'Total Population MOE Appx': 7675.690774138617,
#    'Record Count': 1031,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '533030',
#    'Detailed Occupation': 'Driver/sales workers & truck drivers',
#    'Average Wage': 30688.311741935482,
#    'Average Wage Appx MOE': 15148.821014948217,
#    'Total Population': 3875,
#    'Total Population MOE Appx': 1527.6478938112618,
#    'Record Count': 39,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '537062',
#    'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#    'Average Wage': 25718.498799176577,
#    'Average Wage Appx MOE': 1950.8484000344504,
#    'Total Population': 17488,
#    'Total Population MOE Appx': 3240.395692356384,
#    'Record Count': 180,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'},
#   {'ID Gender': 2,
#    'Gender': 'Female',
#    'ID Year': 2014,
#    'Year': '2014',
#    'ID Employment Time Status': 1,
#    'Employment Time Status': 'Full-time',
#    'ID Detailed Occupation': '412031',
#    'Detailed Occupation': 'Retail salespersons',
#    'Average Wage': 39315.10171982365,
#    'Average Wage Appx MOE': 6253.871446253289,
#    'Total Population': 25177,
#    'Total Population MOE Appx': 3884.6921485664116,
#    'Record Count': 214,
#    'Geography': 'Pennsylvania',
#    'ID Geography': '04000US42'}],
#  'source': [{'measures': ['Average Wage',
#     'Average Wage Appx MOE',
#     'Total Population',
#     'Total Population MOE Appx',
#     'Record Count'],
#    'annotations': {'source_name': 'Census Bureau',
#     'source_description': 'The American Community Survey (ACS) Public Use Microdata Sample (PUMS) files are a set of untabulated records about individual people or housing units. The Census Bureau produces the PUMS files so that data users can create custom tables that are not available through pretabulated (or summary) ACS data products.',
#     'dataset_name': 'ACS PUMS 1-Year Estimate',
#     'dataset_link': 'https://census.gov/programs-surveys/acs/technical-documentation/pums.html',
#     'subtopic': 'Demographics',
#     'table_id': 'PUMS',
#     'topic': 'Diversity',
#     'hidden_measures': 'ygbpop RCA,ygopop RCA,ygipop RCA,yocpop RCA,yiopop RCA,ycbpop RCA'},
#    'name': 'pums_1',
#    'substitutions': [{'id': '04000US42',
#      'dimension': 'Geography',
#      'hierarchy': 'State'}]}]}

# %%
data = response['data']
data
# Out:
# [{'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 70580.63570306363,
#   'Average Wage Appx MOE': 7787.381405961702,
#   'Total Population': 15276,
#   'Total Population MOE Appx': 3029.5955491433274,
#   'Record Count': 141,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '1191XX',
#   'Detailed Occupation': 'Other managers',
#   'Average Wage': 115279.15485869144,
#   'Average Wage Appx MOE': 8044.56391838343,
#   'Total Population': 85239,
#   'Total Population MOE Appx': 7103.747978839758,
#   'Record Count': 866,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 50504.629075994846,
#   'Average Wage Appx MOE': 2010.2457007634227,
#   'Total Population': 118008,
#   'Total Population MOE Appx': 8329.202825593333,
#   'Record Count': 1265,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 36499.6498220552,
#   'Average Wage Appx MOE': 1572.2622030195628,
#   'Total Population': 80362,
#   'Total Population MOE Appx': 6901.113219084553,
#   'Record Count': 853,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 53713.7382821609,
#   'Average Wage Appx MOE': 6478.151307996359,
#   'Total Population': 38595,
#   'Total Population MOE Appx': 4803.748107676571,
#   'Record Count': 377,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 69670.55326140873,
#   'Average Wage Appx MOE': 2283.970364001576,
#   'Total Population': 112896,
#   'Total Population MOE Appx': 8151.263207930433,
#   'Record Count': 1171,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '1191XX',
#   'Detailed Occupation': 'Other managers',
#   'Average Wage': 87194.49822794615,
#   'Average Wage Appx MOE': 8812.261547371932,
#   'Total Population': 51635,
#   'Total Population MOE Appx': 5548.669917416249,
#   'Record Count': 492,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 30100.72416329533,
#   'Average Wage Appx MOE': 7977.0284638266,
#   'Total Population': 5438,
#   'Total Population MOE Appx': 1809.4526874077515,
#   'Record Count': 41,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 29083.289519530532,
#   'Average Wage Appx MOE': 2174.415421012128,
#   'Total Population': 21812,
#   'Total Population MOE Appx': 3617.6750947889655,
#   'Record Count': 219,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2019,
#   'Year': '2019',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 34998.54108853473,
#   'Average Wage Appx MOE': 5276.688219860281,
#   'Total Population': 23279,
#   'Total Population MOE Appx': 3736.7757038783807,
#   'Record Count': 205,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 83065.51539662268,
#   'Average Wage Appx MOE': 14038.405006156008,
#   'Total Population': 14094,
#   'Total Population MOE Appx': 2910.3581582822353,
#   'Record Count': 134,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '1191XX',
#   'Detailed Occupation': 'Other managers',
#   'Average Wage': 105924.46862848008,
#   'Average Wage Appx MOE': 8392.373420615293,
#   'Total Population': 83834,
#   'Total Population MOE Appx': 7045.584301515997,
#   'Record Count': 843,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 50454.15282799535,
#   'Average Wage Appx MOE': 1866.2773952744583,
#   'Total Population': 124735,
#   'Total Population MOE Appx': 8556.353943682463,
#   'Record Count': 1285,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 36696.50969040095,
#   'Average Wage Appx MOE': 1961.2096020313293,
#   'Total Population': 81008,
#   'Total Population MOE Appx': 6927.912399647399,
#   'Record Count': 936,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 52598.29398322653,
#   'Average Wage Appx MOE': 5827.4295873998735,
#   'Total Population': 42448,
#   'Total Population MOE Appx': 5035.627175887831,
#   'Record Count': 377,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 67100.64640559387,
#   'Average Wage Appx MOE': 2193.771404044676,
#   'Total Population': 103828,
#   'Total Population MOE Appx': 7824.046820539053,
#   'Record Count': 1069,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '1191XX',
#   'Detailed Occupation': 'Other managers',
#   'Average Wage': 87815.76518463712,
#   'Average Wage Appx MOE': 8579.97700316148,
#   'Total Population': 44601,
#   'Total Population MOE Appx': 5160.572531859682,
#   'Record Count': 395,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 31418.805937154586,
#   'Average Wage Appx MOE': 4868.417592698289,
#   'Total Population': 6333,
#   'Total Population MOE Appx': 1952.4940158366783,
#   'Record Count': 53,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 29725.878206383397,
#   'Average Wage Appx MOE': 7671.169088483575,
#   'Total Population': 15321,
#   'Total Population MOE Appx': 3034.006994370604,
#   'Record Count': 186,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2018,
#   'Year': '2018',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 38291.085311046285,
#   'Average Wage Appx MOE': 6659.0838582812175,
#   'Total Population': 25366,
#   'Total Population MOE Appx': 3899.758355576344,
#   'Record Count': 238,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 80387.5292524763,
#   'Average Wage Appx MOE': 8351.43107516719,
#   'Total Population': 14033,
#   'Total Population MOE Appx': 2903.9787988122216,
#   'Record Count': 132,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 46920.18295756478,
#   'Average Wage Appx MOE': 2159.360101936477,
#   'Total Population': 117049,
#   'Total Population MOE Appx': 8293.165518648562,
#   'Record Count': 1205,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 37026.13617601296,
#   'Average Wage Appx MOE': 2362.956608108631,
#   'Total Population': 77767,
#   'Total Population MOE Appx': 6789.043745437291,
#   'Record Count': 820,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 53890.172534526355,
#   'Average Wage Appx MOE': 7916.569613806725,
#   'Total Population': 35987,
#   'Total Population MOE Appx': 4639.378567024403,
#   'Record Count': 364,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 67214.166706725,
#   'Average Wage Appx MOE': 2407.951810836023,
#   'Total Population': 104015,
#   'Total Population MOE Appx': 7829.034679319214,
#   'Record Count': 1084,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 32379.270410195142,
#   'Average Wage Appx MOE': 8515.78142956065,
#   'Total Population': 5022,
#   'Total Population MOE Appx': 1738.9150656665563,
#   'Record Count': 35,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 26691.990325900515,
#   'Average Wage Appx MOE': 2880.8483210958425,
#   'Total Population': 14575,
#   'Total Population MOE Appx': 2959.354970971307,
#   'Record Count': 154,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2017,
#   'Year': '2017',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 36084.46999293076,
#   'Average Wage Appx MOE': 5575.887299695561,
#   'Total Population': 26877,
#   'Total Population MOE Appx': 4013.339326481069,
#   'Record Count': 246,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 68129.08447160316,
#   'Average Wage Appx MOE': 9374.737873317727,
#   'Total Population': 11128,
#   'Total Population MOE Appx': 2586.7694794322006,
#   'Record Count': 112,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 47333.438450220696,
#   'Average Wage Appx MOE': 2180.591265354683,
#   'Total Population': 112145,
#   'Total Population MOE Appx': 8120.987959637961,
#   'Record Count': 1166,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 35233.155072151625,
#   'Average Wage Appx MOE': 1680.5603594084755,
#   'Total Population': 69645,
#   'Total Population MOE Appx': 6429.973482235003,
#   'Record Count': 793,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 49648.41920105613,
#   'Average Wage Appx MOE': 6261.089810592783,
#   'Total Population': 40904,
#   'Total Population MOE Appx': 4943.3278498244445,
#   'Record Count': 383,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 64723.68338400152,
#   'Average Wage Appx MOE': 1918.6607207567467,
#   'Total Population': 105260,
#   'Total Population MOE Appx': 7873.77936540808,
#   'Record Count': 1027,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 36137.982989064396,
#   'Average Wage Appx MOE': 6663.6435362667025,
#   'Total Population': 4115,
#   'Total Population MOE Appx': 1574.22016128314,
#   'Record Count': 40,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 28289.153297026787,
#   'Average Wage Appx MOE': 2929.681640076672,
#   'Total Population': 13588,
#   'Total Population MOE Appx': 2857.6601465514423,
#   'Record Count': 155,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2016,
#   'Year': '2016',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 31106.45618633664,
#   'Average Wage Appx MOE': 3195.410229906362,
#   'Total Population': 30139,
#   'Total Population MOE Appx': 4248.275986927075,
#   'Record Count': 264,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 68907.87305976807,
#   'Average Wage Appx MOE': 7856.027814096758,
#   'Total Population': 11210,
#   'Total Population MOE Appx': 2596.2266696317974,
#   'Record Count': 115,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 46087.886521691136,
#   'Average Wage Appx MOE': 1878.0942702634852,
#   'Total Population': 117767,
#   'Total Population MOE Appx': 8315.715849752376,
#   'Record Count': 1228,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 33792.24082690688,
#   'Average Wage Appx MOE': 1603.8125600291403,
#   'Total Population': 77155,
#   'Total Population MOE Appx': 6761.575169645143,
#   'Record Count': 842,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 47700.442837798626,
#   'Average Wage Appx MOE': 5678.849510661155,
#   'Total Population': 41356,
#   'Total Population MOE Appx': 4970.085723875826,
#   'Record Count': 381,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 64629.08175520099,
#   'Average Wage Appx MOE': 2131.0429358543192,
#   'Total Population': 98587,
#   'Total Population MOE Appx': 7624.898524989344,
#   'Record Count': 1014,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 26274.930133333335,
#   'Average Wage Appx MOE': 7505.241246812428,
#   'Total Population': 3750,
#   'Total Population MOE Appx': 1502.835977869389,
#   'Record Count': 40,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 28248.533596586203,
#   'Average Wage Appx MOE': 2844.966101487863,
#   'Total Population': 15701,
#   'Total Population MOE Appx': 3071.0633119845756,
#   'Record Count': 189,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2015,
#   'Year': '2015',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 28734.92122879413,
#   'Average Wage Appx MOE': 3369.9606819089367,
#   'Total Population': 21810,
#   'Total Population MOE Appx': 3617.100454932424,
#   'Record Count': 231,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 65841.13802545886,
#   'Average Wage Appx MOE': 9820.507819069951,
#   'Total Population': 13512,
#   'Total Population MOE Appx': 2849.578358998793,
#   'Record Count': 129,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 44708.86606590023,
#   'Average Wage Appx MOE': 1894.6654564305932,
#   'Total Population': 119514,
#   'Total Population MOE Appx': 8373.947642739826,
#   'Record Count': 1254,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 33659.893253259754,
#   'Average Wage Appx MOE': 2066.6487965911433,
#   'Total Population': 73932,
#   'Total Population MOE Appx': 6620.463302269277,
#   'Record Count': 797,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 1,
#   'Gender': 'Male',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 55570.49864715903,
#   'Average Wage Appx MOE': 8341.752534083873,
#   'Total Population': 39916,
#   'Total Population MOE Appx': 4883.268918512485,
#   'Record Count': 355,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '291141',
#   'Detailed Occupation': 'Registered nurses',
#   'Average Wage': 62452.38368661658,
#   'Average Wage Appx MOE': 2366.87128349608,
#   'Total Population': 99967,
#   'Total Population MOE Appx': 7675.690774138617,
#   'Record Count': 1031,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '533030',
#   'Detailed Occupation': 'Driver/sales workers & truck drivers',
#   'Average Wage': 30688.311741935482,
#   'Average Wage Appx MOE': 15148.821014948217,
#   'Total Population': 3875,
#   'Total Population MOE Appx': 1527.6478938112618,
#   'Record Count': 39,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '537062',
#   'Detailed Occupation': 'Laborers & freight, stock, & material movers, hand',
#   'Average Wage': 25718.498799176577,
#   'Average Wage Appx MOE': 1950.8484000344504,
#   'Total Population': 17488,
#   'Total Population MOE Appx': 3240.395692356384,
#   'Record Count': 180,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'},
#  {'ID Gender': 2,
#   'Gender': 'Female',
#   'ID Year': 2014,
#   'Year': '2014',
#   'ID Employment Time Status': 1,
#   'Employment Time Status': 'Full-time',
#   'ID Detailed Occupation': '412031',
#   'Detailed Occupation': 'Retail salespersons',
#   'Average Wage': 39315.10171982365,
#   'Average Wage Appx MOE': 6253.871446253289,
#   'Total Population': 25177,
#   'Total Population MOE Appx': 3884.6921485664116,
#   'Record Count': 214,
#   'Geography': 'Pennsylvania',
#   'ID Geography': '04000US42'}]

# %%
# Set empty lists to hold data needed 

ID_Geography = []
Gender = []
Time_Status = []
Detailed_Occupation = []
ID_Year = []
Avg_Wage = []
Total_Population = []

# Loop through each salary info
for info in data:
    ID_Geography.append(info['ID Geography'])
    Gender.append(info['Gender'])
    Time_Status.append(info['Employment Time Status'])
    Detailed_Occupation.append(info['Detailed Occupation'])
    ID_Year.append(info['ID Year'])
    Avg_Wage.append(info['Average Wage'])
    Total_Population.append(info['Total Population'])

# %%
#create table to put see data
data_summary = {"Gender":Gender, "ID_Geography":ID_Geography, "Full_or_Part_Time": Time_Status, "Title":Detailed_Occupation, "Year": ID_Year, "Avg Salary": Avg_Wage, "Total_Population": Total_Population}
data_summary_df = pd.DataFrame(data_summary)
data_summary_df
# Out:
#     Gender ID_Geography Full_or_Part_Time  \
# 0     Male    04000US42         Full-time
# 1     Male    04000US42         Full-time
# 2     Male    04000US42         Full-time
# 3     Male    04000US42         Full-time
# 4     Male    04000US42         Full-time
# 5   Female    04000US42         Full-time
# 6   Female    04000US42         Full-time
# 7   Female    04000US42         Full-time
# 8   Female    04000US42         Full-time
# 9   Female    04000US42         Full-time
# 10    Male    04000US42         Full-time
# 11    Male    04000US42         Full-time
# 12    Male    04000US42         Full-time
# 13    Male    04000US42         Full-time
# 14    Male    04000US42         Full-time
# 15  Female    04000US42         Full-time
# 16  Female    04000US42         Full-time
# 17  Female    04000US42         Full-time
# 18  Female    04000US42         Full-time
# 19  Female    04000US42         Full-time
# 20    Male    04000US42         Full-time
# 21    Male    04000US42         Full-time
# 22    Male    04000US42         Full-time
# 23    Male    04000US42         Full-time
# 24  Female    04000US42         Full-time
# 25  Female    04000US42         Full-time
# 26  Female    04000US42         Full-time
# 27  Female    04000US42         Full-time
# 28    Male    04000US42         Full-time
# 29    Male    04000US42         Full-time
# 30    Male    04000US42         Full-time
# 31    Male    04000US42         Full-time
# 32  Female    04000US42         Full-time
# 33  Female    04000US42         Full-time
# 34  Female    04000US42         Full-time
# 35  Female    04000US42         Full-time
# 36    Male    04000US42         Full-time
# 37    Male    04000US42         Full-time
# 38    Male    04000US42         Full-time
# 39    Male    04000US42         Full-time
# 40  Female    04000US42         Full-time
# 41  Female    04000US42         Full-time
# 42  Female    04000US42         Full-time
# 43  Female    04000US42         Full-time
# 44    Male    04000US42         Full-time
# 45    Male    04000US42         Full-time
# 46    Male    04000US42         Full-time
# 47    Male    04000US42         Full-time
# 48  Female    04000US42         Full-time
# 49  Female    04000US42         Full-time
# 50  Female    04000US42         Full-time
# 51  Female    04000US42         Full-time
#
#                                                 Title  Year     Avg Salary  \
# 0                                   Registered nurses  2019   70580.635703
# 1                                      Other managers  2019  115279.154859
# 2                Driver/sales workers & truck drivers  2019   50504.629076
# 3   Laborers & freight, stock, & material movers, ...  2019   36499.649822
# 4                                 Retail salespersons  2019   53713.738282
# 5                                   Registered nurses  2019   69670.553261
# 6                                      Other managers  2019   87194.498228
# 7                Driver/sales workers & truck drivers  2019   30100.724163
# 8   Laborers & freight, stock, & material movers, ...  2019   29083.289520
# 9                                 Retail salespersons  2019   34998.541089
# 10                                  Registered nurses  2018   83065.515397
# 11                                     Other managers  2018  105924.468628
# 12               Driver/sales workers & truck drivers  2018   50454.152828
# 13  Laborers & freight, stock, & material movers, ...  2018   36696.509690
# 14                                Retail salespersons  2018   52598.293983
# 15                                  Registered nurses  2018   67100.646406
# 16                                     Other managers  2018   87815.765185
# 17               Driver/sales workers & truck drivers  2018   31418.805937
# 18  Laborers & freight, stock, & material movers, ...  2018   29725.878206
# 19                                Retail salespersons  2018   38291.085311
# 20                                  Registered nurses  2017   80387.529252
# 21               Driver/sales workers & truck drivers  2017   46920.182958
# 22  Laborers & freight, stock, & material movers, ...  2017   37026.136176
# 23                                Retail salespersons  2017   53890.172535
# 24                                  Registered nurses  2017   67214.166707
# 25               Driver/sales workers & truck drivers  2017   32379.270410
# 26  Laborers & freight, stock, & material movers, ...  2017   26691.990326
# 27                                Retail salespersons  2017   36084.469993
# 28                                  Registered nurses  2016   68129.084472
# 29               Driver/sales workers & truck drivers  2016   47333.438450
# 30  Laborers & freight, stock, & material movers, ...  2016   35233.155072
# 31                                Retail salespersons  2016   49648.419201
# 32                                  Registered nurses  2016   64723.683384
# 33               Driver/sales workers & truck drivers  2016   36137.982989
# 34  Laborers & freight, stock, & material movers, ...  2016   28289.153297
# 35                                Retail salespersons  2016   31106.456186
# 36                                  Registered nurses  2015   68907.873060
# 37               Driver/sales workers & truck drivers  2015   46087.886522
# 38  Laborers & freight, stock, & material movers, ...  2015   33792.240827
# 39                                Retail salespersons  2015   47700.442838
# 40                                  Registered nurses  2015   64629.081755
# 41               Driver/sales workers & truck drivers  2015   26274.930133
# 42  Laborers & freight, stock, & material movers, ...  2015   28248.533597
# 43                                Retail salespersons  2015   28734.921229
# 44                                  Registered nurses  2014   65841.138025
# 45               Driver/sales workers & truck drivers  2014   44708.866066
# 46  Laborers & freight, stock, & material movers, ...  2014   33659.893253
# 47                                Retail salespersons  2014   55570.498647
# 48                                  Registered nurses  2014   62452.383687
# 49               Driver/sales workers & truck drivers  2014   30688.311742
# 50  Laborers & freight, stock, & material movers, ...  2014   25718.498799
# 51                                Retail salespersons  2014   39315.101720
#
#     Total_Population
# 0              15276
# 1              85239
# 2             118008
# 3              80362
# 4              38595
# 5             112896
# 6              51635
# 7               5438
# 8              21812
# 9              23279
# 10             14094
# 11             83834
# 12            124735
# 13             81008
# 14             42448
# 15            103828
# 16             44601
# 17              6333
# 18             15321
# 19             25366
# 20             14033
# 21            117049
# 22             77767
# 23             35987
# 24            104015
# 25              5022
# 26             14575
# 27             26877
# 28             11128
# 29            112145
# 30             69645
# 31             40904
# 32            105260
# 33              4115
# 34             13588
# 35             30139
# 36             11210
# 37            117767
# 38             77155
# 39             41356
# 40             98587
# 41              3750
# 42             15701
# 43             21810
# 44             13512
# 45            119514
# 46             73932
# 47             39916
# 48             99967
# 49              3875
# 50             17488
# 51             25177

# %%
#stats table
data_stats_df= data_summary_df[["Avg Salary"]].agg(['count','mean', 'std', 'min',  'max'])
data_stats_df
# Out:
#           Avg Salary
# count      52.000000
# mean    50081.585171
# std     21297.838823
# min     25718.498799
# max    115279.154859

# %%
#save to csv
data_summary_df.to_csv("salary_summary_df.csv", encoding="utf-8", index=False)

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///philly.sqlite', echo=True)
sqlite_connection = engine.connect()

# Add primary key to "merged" table that contains all cleaned data
sqlite_connection.execute('DROP TABLE "query_url"' )
sqlite_connection.execute('CREATE TABLE "query_url" ( "index" INTEGER PRIMARY KEY, "ID_Geography" TEXT, "Gender" TEXT, "Full_or_Part_Time" TEXT, "Title" TEXT, "Year" INTEGER, "Avg Salary" INTEGER, "Total_Population" INTEGER)' )
# Out:
# 2021-04-30 19:59:37,510 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-04-30 19:59:37,513 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-30 19:59:37,514 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-04-30 19:59:37,515 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-30 19:59:37,516 INFO sqlalchemy.engine.base.Engine DROP TABLE "query_url"
# 2021-04-30 19:59:37,517 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-30 19:59:37,525 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-04-30 19:59:37,526 INFO sqlalchemy.engine.base.Engine CREATE TABLE "query_url" ( "index" INTEGER PRIMARY KEY, "ID_Geography" TEXT, "Gender" TEXT, "Full_or_Part_Time" TEXT, "Title" TEXT, "Year" INTEGER, "Avg Salary" INTEGER, "Total_Population" INTEGER)
# 2021-04-30 19:59:37,527 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-30 19:59:37,533 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
sqlite_table = "query_url"
data_summary_df.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=True, )
# Out:
# 2021-04-28 18:52:55,974 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("query_url")
# 2021-04-28 18:52:55,976 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-28 18:52:56,085 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("query_url")
# 2021-04-28 18:52:56,086 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-28 18:52:56,088 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE query_url (
# 	"index" BIGINT,
# 	"Gender" TEXT,
# 	"ID_Geography" TEXT,
# 	"Full_or_Part_Time" TEXT,
# 	"Title" TEXT,
# 	"Year" BIGINT,
# 	"Avg Salary" FLOAT,
# 	"Total_Population" BIGINT
# )
#
#
# 2021-04-28 18:52:56,088 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-28 18:52:56,104 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-04-28 18:52:56,105 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_query_url_index ON query_url ("index")
# 2021-04-28 18:52:56,106 INFO sqlalchemy.engine.base.Engine ()
# 2021-04-28 18:52:56,109 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-04-28 18:52:56,129 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-04-28 18:52:56,133 INFO sqlalchemy.engine.base.Engine INSERT INTO query_url ("index", "Gender", "ID_Geography", "Full_or_Part_Time", "Title", "Year", "Avg Salary", "Total_Population") VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2021-04-28 18:52:56,142 INFO sqlalchemy.engine.base.Engine ((0, 'Male', '04000US42', 'Full-time', 'Registered nurses', 2019, 70580.63570306363, 15276), (1, 'Male', '04000US42', 'Full-time', 'Other managers', 2019, 115279.15485869144, 85239), (2, 'Male', '04000US42', 'Full-time', 'Driver/sales workers & truck drivers', 2019, 50504.629075994846, 118008), (3, 'Male', '04000US42', 'Full-time', 'Laborers & freight, stock, & material movers, hand', 2019, 36499.6498220552, 80362), (4, 'Male', '04000US42', 'Full-time', 'Retail salespersons', 2019, 53713.7382821609, 38595), (5, 'Female', '04000US42', 'Full-time', 'Registered nurses', 2019, 69670.55326140873, 112896), (6, 'Female', '04000US42', 'Full-time', 'Other managers', 2019, 87194.49822794615, 51635), (7, 'Female', '04000US42', 'Full-time', 'Driver/sales workers & truck drivers', 2019, 30100.72416329533, 5438)  ... displaying 10 of 52 total bound parameter sets ...  (50, 'Female', '04000US42', 'Full-time', 'Laborers & freight, stock, & material movers, hand', 2014, 25718.498799176577, 17488), (51, 'Female', '04000US42', 'Full-time', 'Retail salespersons', 2014, 39315.10171982365, 25177))
# 2021-04-28 18:52:56,147 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
sqlite_connection.close()
