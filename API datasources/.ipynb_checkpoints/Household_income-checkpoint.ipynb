# %%
import json
import pandas as pd

# %%
# Load Data to dict

with open('Resources/data.json','r') as f:
    data = json.loads(f.read())

# Load Data to pandas Data Frame
df_list = pd.DataFrame.from_dict(data["data"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-eaf37e397328> in <module>
#       1 # Load Data to dict
#       2
# ----> 3 with open('Resources/data.json','r') as f:
#       4     data = json.loads(f.read())
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/data.json'

# %%
# Save data to csv 
df_list.to_csv("Resources/Household_income.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3c9e7be7910b> in <module>
#       1 # Save data to csv
# ----> 2 df_list.to_csv("Resources/Household_income.csv")
#
# NameError: name 'df_list' is not defined

# %%
df_list
# Out:
#       ID Year  Year  ID Race   Race  Household Income by Race  \
# 0        2018  2018        0  Total                    102448
# 1        2018  2018        0  Total                     47243
# 2        2018  2018        0  Total                     91354
# 3        2018  2018        0  Total                     62821
# 4        2018  2018        0  Total                     78648
# ...       ...   ...      ...    ...                       ...
# 2243     2013  2013        0  Total                     39886
# 2244     2013  2013        0  Total                     30081
# 2245     2013  2013        0  Total                     39861
# 2246     2013  2013        0  Total                     66250
# 2247     2013  2013        0  Total                    100313
#
#       Household Income by Race Moe  \
# 0                          16740.0
# 1                          14803.0
# 2                          18636.0
# 3                          10734.0
# 4                           6162.0
# ...

# %%
# Remove columns not being used for analysis
prison_df.drop(columns =['abbreviation','staff_tests','staff_recovered','prisoners_recovered','staff_tests_with_multiples','prisoner_tests','prisoner_tests_with_multiples','notes','as_of_date'], inplace = True)

# %%
#Write to Postgres.

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://localhost:5432/mydatabase')
df_list.to_sql('household_income', engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
# ...
